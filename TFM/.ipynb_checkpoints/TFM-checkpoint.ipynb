# %%
import pandas as pd

# %%
limpio = pd.read_excel("archivo_limpiado.xlsx")

# %%
limpio
# Out:
#                              autor                           etiqueta  \
# 0     Abakanowicz, Magdalena:1930:  Magdalena Abakanowicz (1930-2017)
# 1                Abraham, Ayisha::             Ayisha Abraham (1963-)
# 2              Abramowicz, Janet::           Janet Abramowicz (1950-)
# 3                Abts, Tomma:1967:                 Tomma Abts (1967-)
# 4             Accardi, Carla:1924:          Carla Accardi (1924-2014)
# ...                            ...                                ...
# 2145          Torres, Carola:1927:          Carola Torres (1927-2017)
# 2146         Vicens, Clarina:1938:             Clarina Vicens (1938-)
# 2147             Virta, Ulla:1946:                 Ulla Virta (1946-)
# 2148           Yanase, Hisae:1943:           Hisae Yanase (1943-2019)
# 2149        Zapisek, Adriana:1949:            Adriana Zapisek (1949-)
#
#                                             descripcion  \
# 0                                      Escultora polaca
# ...
