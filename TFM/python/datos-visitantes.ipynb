# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns #importo la libreria

# %%
visitantes = pd.read_excel("datos/visitantes/corregida-visitantes-sexo.xls")

# %% [markdown]
# # PORCENTAJE DE VISITANTES DE LOS MUSEOS ESPAÑOLES

# %%
hombres = visitantes.loc[3, 'Column2']
mujeres = visitantes.loc[4, 'Column2']
datos = [hombres, mujeres]
etiquetas = ['Hombres', 'Mujeres']
colores = ['#B68B67', '#FCD9BC']

# %%
plt.pie(datos, colors=colores, autopct='%1.1f%%')
plt.axis('equal')  # Para que el gráfico de pastel sea circular
plt.legend(etiquetas)
plt.show()

# %%
# VISITANTES POR RANGOS DE EDAD

# %%
personas_1519 = visitantes.loc[5, 'Column2']
personas_2024 = visitantes.loc[6, 'Column2']
personas_2534 = visitantes.loc[7, 'Column2']
personas_3544 = visitantes.loc[8, 'Column2']
personas_4554 = visitantes.loc[9, 'Column2']
personas_5564 = visitantes.loc[10, 'Column2']
personas_6574 = visitantes.loc[11, 'Column2']
personas_75 = visitantes.loc[12, 'Column2']

# %%
datos = [personas_1519,personas_2024,personas_2534,personas_3544,personas_4554,personas_5564,personas_6574,personas_75]
etiquetas = ['15-19 años', ' 20-24 años', '25-34', '35-44', '45-54', '55-64', '65-74', 'Más de 75']

# %%
# Invertir los datos y etiquetas
datos = datos[::-1]
etiquetas = etiquetas[::-1]
# Creo el gráfico de 
plt.bar(etiquetas, datos, color='#FCD9BC')

# Personalizo el gráfico
plt.xlabel('Rango de edad')
plt.ylabel('Porcentaje de visitantes')
plt.show()

# %%
profesiones = pd.read_excel("datos/visitantes/visitaok.xls")

# %%
profesiones
# Out:
#    Encuesta de Hábitos y Prácticas Culturales 2021-2022  \
# 0
# 1
# 2
# 3                                               TOTAL
# 4                                             Hombres
# 5                                             Mujeres
# 6                                     De 15 a 24 años
# 7                                     De 25 a 34 años
# 8                                     De 35 a 44 años
# 9                                     De 45 a 54 años
# 10                             De 55 años en adelante
# 11                                             Notas:
# 12                                           Fuente:
# 13  Ministerio de Cultura y Deporte. Encuesta de H...
#
#                           Column     Column2    Column3  \
# 0                         Museos         NaN        NaN
# 1   Total han visitado en un año  profesión       ocio
# 2                      2021-2022   2021-2022  2021-2022
# 3                            100         6.3       93.7
# 4                            100         6.3       93.7
# 5                            100         6.3       93.7
# 6                            100        14.3       85.7
# 7                            100         5.5       94.5
# 8                            100         6.2       93.8
# 9                            100         4.4       95.6
# 10                           100         3.7       96.3
# 11                           NaN         NaN        NaN
# 12                           NaN         NaN        NaN
# 13                           NaN         NaN        NaN
#
#                          Column4                   Column5  \
# 0                   Exposiciones                       NaN
# 1   Total han visitado en un año  Por profesión o estudios
# 2                      2021-2022                 2021-2022
# 3                            100                       8.6
# 4                            100                       8.5
# 5                            100                       8.7
# 6                            100                      24.5
# 7                            100                       5.5
# 8                            100                       6.6
# 9                            100                       5.8
# 10                           100                       5.1
# 11                           NaN                       NaN
# 12                           NaN                       NaN
# 13                           NaN                       NaN
#
#                        Column6                       Column7  \
# 0                          NaN              Galerías de arte
# 1   Por ocio o entretenimiento  Total han visitado en un año
# 2                    2021-2022                     2021-2022
# 3                         91.4                           100
# 4                         91.5                           100
# 5                         91.3                           100
# 6                         75.5                           100
# 7                         94.5                           100
# 8                         93.4                           100
# 9                         94.2                           100
# 10                        94.9                           100
# 11                         NaN                           NaN
# 12                         NaN                           NaN
# 13                         NaN                           NaN
#
#                      Column8                     Column9  \
# 0                        NaN                         NaN
# 1   Por profesión o estudios  Por ocio o entretenimiento
# 2                  2021-2022                   2021-2022
# 3                        6.9                        93.1
# 4                        6.9                        93.1
# 5                          7                          93
# 6                       20.1                        79.9
# 7                        2.3                        97.7
# 8                          6                          94
# 9                        4.8                        95.2
# 10                       4.1                        95.9
# 11                       NaN                         NaN
# 12                       NaN                         NaN
# 13                       NaN                         NaN
#
#                         Column10                 Column 12  \
# 0                     Monumentos                       NaN
# 1   Total han visitado en un año  Por profesión o estudios
# 2                      2021-2022                 2021-2022
# 3                            100                         4
# 4                            100                       4.8
# 5                            100                       3.2
# 6                            100                      10.4
# 7                            100                       2.4
# 8                            100                       3.7
# 9                            100                         3
# 10                           100                       2.5
# 11                           NaN                       NaN
# 12                           NaN                       NaN
# 13                           NaN                       NaN
#
#                      Column 13                     Column 14  \
# 0                          NaN     Yacimientos arqueológicos
# 1   Por ocio o entretenimiento  Total han visitado en un año
# 2                    2021-2022                     2021-2022
# 3                           96                           100
# 4                         95.2                           100
# 5                         96.8                           100
# 6                         89.6                           100
# 7                         97.6                           100
# 8                         96.3                           100
# 9                           97                           100
# 10                        97.5                           100
# 11                         NaN                           NaN
# 12                         NaN                           NaN
# 13                         NaN                           NaN
#
#                    Column 15                   Column 16  \
# 0                        NaN                         NaN
# 1   Por profesión o estudios  Por ocio o entretenimiento
# 2                  2021-2022                   2021-2022
# 3                        5.1                        94.9
# 4                        5.5                        94.5
# 5                        4.6                        95.4
# 6                         16                          84
# 7                        4.6                        95.4
# 8                        5.3                        94.7
# 9                        2.8                        97.2
# 10                       2.4                        97.6
# 11                       NaN                         NaN
# 12                       NaN                         NaN
# 13                       NaN                         NaN
#
#                        Column 17                 Column 18  \
# 0                       Archivos                       NaN
# 1   Total han visitado en un año  Por profesión o estudios
# 2                      2021-2022                 2021-2022
# 3                            100                      36.7
# 4                            100                      33.6
# 5                            100                        40
# 6                            100                      53.5
# 7                            100                      24.1
# 8                            100                      31.5
# 9                            100                      37.8
# 10                           100                      34.9
# 11                           NaN                       NaN
# 12                           NaN                       NaN
# 13                           NaN                       NaN
#
#                      Column 19
# 0                          NaN
# 1   Por ocio o entretenimiento
# 2                    2021-2022
# 3                         63.3
# 4                         66.4
# 5                           60
# 6                         46.5
# 7                         75.9
# 8                         68.5
# 9                         62.2
# 10                        65.1
# 11                         NaN
# 12                         NaN
# 13                         NaN

# %%
ocio = profesiones.loc[3, 'Column2']
profesion = profesiones.loc[3, 'Column3']

# %%
datos = [ocio, profesion]
etiquetas = ['Ocio', 'Profesión']
colores = ['#B68B67', '#FCD9BC']

# %%
plt.pie(datos, labels=etiquetas, colors=colores, autopct='%1.1f%%')
plt.title('Visitas a los museos por motivación')



plt.show()
